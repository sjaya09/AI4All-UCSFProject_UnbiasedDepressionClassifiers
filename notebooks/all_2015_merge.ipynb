# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
acculturation_2015_df = pd.read_csv('2015-2016_acculturation.csv')
alcohol_use_2015_df = pd.read_csv('2015-2016_alcohol_use.csv')
bp_cholesterol_2015_df = pd.read_csv('2015-2016_bp_cholesterol.csv')
cardiovascular_2015_df = pd.read_csv('2015-2016_cardiovascular.csv')
consumer_behavior_2015_df = pd.read_csv('2015-2016_consumer_behavior.csv')
demographic_2015_df = pd.read_csv('2015-2016_demographic.csv')
dermatology_2015_df = pd.read_csv('2015-2016_dermatology.csv')
diabetes_2015_df = pd.read_csv('2015-2016_diabetes.csv')
diet_nutrition_2015_df = pd.read_csv('2015-2016_diet_nutrition.csv')
drug_use_2015_df = pd.read_csv('2015-2016_drug_use.csv')
early_childhood_2015_df = pd.read_csv('2015-2016_early_childhood.csv')
food_security_2015_df = pd.read_csv('2015-2016_food_security.csv')
health_insurance_2015_df = pd.read_csv('2015-2016_health_insurance.csv')
health_status_2015_df = pd.read_csv('2015-2016_health_status.csv')
hospital_access_to_care_2015_df = pd.read_csv('2015-2016_hospital_access_to_care.csv')
housing_2015_df = pd.read_csv('2015-2016_housing.csv')
immunization_2015_df = pd.read_csv('2015-2016_immunization.csv')
income_2015_df = pd.read_csv('2015-2016_income.csv')
medical_conditions_2015_df = pd.read_csv('2015-2016_medical_conditions.csv')
mental_health_2015_df = pd.read_csv('2015-2016_mental_health.csv')
occupation_2015_df = pd.read_csv('2015-2016_occupation.csv')
oral_health_2015_df = pd.read_csv('2015-2016_oral_health.csv')
pesticide_use_2015_df = pd.read_csv('2015-2016_pesticide_use.csv')
physical_activity_2015_df = pd.read_csv('2015-2016_physical_activity.csv')
physical_functioning_2015_df = pd.read_csv('2015-2016_physical_functioning.csv')
preventative_aspirin_use_2015_df = pd.read_csv('2015-2016_preventative_aspirin_use.csv')
reproductive_2015_df = pd.read_csv('2015-2016_reproductive.csv')
sexual_behavior_2015_df = pd.read_csv('2015-2016_sexual_behavior.csv')
sleep_disorder_2015_df = pd.read_csv('2015-2016_sleep_disorder.csv')
smoking_cigarette_2015_df = pd.read_csv('2015-2016_smoking_cigarette.csv')
smoking_recent_tobacco_2015_df = pd.read_csv('2015-2016_smoking_recent_tobacco.csv')
urology_2015_df = pd.read_csv('2015-2016_urology.csv')
weight_history_2015_df = pd.read_csv('2015-2016_weight_history.csv')

# %%
all_2015_df = acculturation_2015_df.merge(alcohol_use_2015_df, how='outer')
df_list = [alcohol_use_2015_df,
            bp_cholesterol_2015_df, 
           cardiovascular_2015_df,
          consumer_behavior_2015_df, 
          demographic_2015_df,
           dermatology_2015_df,
           diabetes_2015_df,
           diet_nutrition_2015_df,
           drug_use_2015_df, 
           early_childhood_2015_df,
           food_security_2015_df,
           health_insurance_2015_df, 
           health_status_2015_df, 
           hospital_access_to_care_2015_df, 
           housing_2015_df,
           immunization_2015_df,
           income_2015_df,
           medical_conditions_2015_df,
           mental_health_2015_df,
           occupation_2015_df,
           oral_health_2015_df,
           pesticide_use_2015_df,
           physical_activity_2015_df,
           physical_functioning_2015_df,
           preventative_aspirin_use_2015_df,
           reproductive_2015_df,
           sexual_behavior_2015_df,
           sleep_disorder_2015_df,
           smoking_cigarette_2015_df,
           smoking_recent_tobacco_2015_df,
           urology_2015_df,
           weight_history_2015_df, 
          ]
for df in df_list:
    all_2015_df = all_2015_df.merge(df, how='outer')

all_2015_df.to_csv('all_2015_df.csv', index=False)
# Out:
#          SEQN  ACD011A  ACD011B  ACD011C  ACD040  ACD110  ALQ101  ALQ110  \
# 0     83732.0      1.0      NaN      NaN     NaN     NaN     1.0     NaN
# 1     83733.0      NaN      NaN      9.0     NaN     NaN     1.0     NaN
# 2     83734.0      1.0      NaN      NaN     NaN     NaN     1.0     NaN
# 3     83735.0      1.0      NaN      NaN     NaN     NaN     2.0     1.0
# 4     83736.0      1.0      NaN      NaN     NaN     NaN     2.0     1.0
# ...       ...      ...      ...      ...     ...     ...     ...     ...
# 9966  93635.0      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 9967  93678.0      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 9968  93688.0      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 9969  93692.0      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 9970  93698.0      NaN      NaN      NaN     NaN     NaN     NaN     NaN
#
#            ALQ120Q  ALQ120U  ...  WHD080Q  WHD080R  WHD080S  WHD080T  WHD080L  \
# ...
