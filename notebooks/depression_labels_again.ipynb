# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import data

# %%
mental_health_df = pd.read_csv('mental_health_df.csv')
mental_health_df
# Out:
#              DPQ010        DPQ020        DPQ030        DPQ040        DPQ050  \
# 0      5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 1      1.000000e+00  5.397605e-79  1.000000e+00  1.000000e+00  1.000000e+00
# 2      1.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 3      5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 4      5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# ...             ...           ...           ...           ...           ...
# 15508  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 15509  5.397605e-79  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79
# 15510  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 15511  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 15512  5.397605e-79  5.397605e-79  1.000000e+00  1.000000e+00  5.397605e-79
#
# ...

# %% [markdown]
# ### Format the data
# So... \
# I should've done this in the last notebook (I totally could've with the handy copy-paste function I had) but it's not too late to ~~copy Albert's code and~~ do it now.

# %%
# not in use
def mh(x):
    if x == '\.':
        return 'missing'
    elif x == 1:
        return 'several days'
    elif x == 2:
        return 'more than half the days'
    elif x == 3:
        return 'nearly every day'
    elif x == 7:
        return 'refused'
    elif x == 9:
        return "don't know"
    else:
        return 'not at all'

for col in mental_health_df.columns:
    mental_health_df[col] = mental_health_df[col].apply(lambda x: mh(x))

mental_health_df
# Out:
#              DPQ010                   DPQ020        DPQ030        DPQ040  \
# 0        not at all               not at all    not at all    not at all
# 1      several days               not at all  several days  several days
# 2      several days  more than half the days  several days  several days
# 3        not at all               not at all    not at all    not at all
# 4        not at all               not at all    not at all    not at all
# ...             ...                      ...           ...           ...
# 15508    not at all               not at all    not at all    not at all
# 15509    not at all             several days    not at all    not at all
# 15510    not at all               not at all    not at all    not at all
# 15511    not at all               not at all    not at all    not at all
# 15512    not at all               not at all  several days  several days
#
#              DPQ050                   DPQ060      DPQ070        DPQ080  \
# ...

# %% [markdown]
# ## Categorize values
# ### Make a function

# %%
# not in use
def calc(row):
    sum = 0
    for i in range(1, 11): # because there are 10 questions
        if row[i] == 'several days':
            sum += 1
        if row[i] == 'more than half the days':
            sum += 2
        if row[i] == 'nearly every day':
            sum += 3
    return sum

# %%
def categ(val):
    if val >= 0 and val <= 4:
        return "minimal"
    elif val >= 5 and val <= 9:
        return "mild"
    elif val >= 10 and val <= 14:
        return "moderate"
    elif val >= 15 and val <= 19:
        return "moderately severe"
    else:
        return "severe"

# %%
def add(row):
    sum = 0
    for i in range(0, 10):
        sum += float(row[i])
    return sum

# %%
mental_health_df.columns
# Out:
# Index(['DPQ010', 'DPQ020', 'DPQ030', 'DPQ040', 'DPQ050', 'DPQ060', 'DPQ070',
#        'DPQ080', 'DPQ090', 'DPQ100', 'depression_level', 'depression_level_2',
#        'depression_level_3', 'depression_level_4', 'depression_level_5',
#        'depression_level_6', 'depression_level_7', 'depression_level_8',
#        'depression_level_9', 'depression_level_10', 'labels_raw', 'labels'],
#       dtype='object')

# %%
# not in use
mental_health_df['labels_raw'] = mental_health_df.apply(calc, axis=1)
mental_health_df['labels'] = mental_health_df['labels_raw'].apply(lambda x: categ(x))
mental_health_df[['DPQ010', 'DPQ020', 'DPQ030', 'DPQ040', 'DPQ050', 'DPQ060', 'DPQ070',
       'DPQ080', 'DPQ090', 'DPQ100', 'labels_raw', 'labels']]
# Out:
#              DPQ010                   DPQ020        DPQ030        DPQ040  \
# 0        not at all               not at all    not at all    not at all
# 1      several days               not at all  several days  several days
# 2      several days  more than half the days  several days  several days
# 3        not at all               not at all    not at all    not at all
# 4        not at all               not at all    not at all    not at all
# ...             ...                      ...           ...           ...
# 15508    not at all               not at all    not at all    not at all
# 15509    not at all             several days    not at all    not at all
# 15510    not at all               not at all    not at all    not at all
# 15511    not at all               not at all    not at all    not at all
# 15512    not at all               not at all  several days  several days
#
#              DPQ050                   DPQ060      DPQ070        DPQ080  \
# ...

# %%
# debug check
mental_health_df = mental_health_df.fillna(0)
mental_health_df
# Out:
#              DPQ010        DPQ020        DPQ030        DPQ040        DPQ050  \
# 0      5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 1      1.000000e+00  5.397605e-79  1.000000e+00  1.000000e+00  1.000000e+00
# 2      1.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 3      5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 4      5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# ...             ...           ...           ...           ...           ...
# 15508  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 15509  5.397605e-79  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79
# 15510  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 15511  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 15512  5.397605e-79  5.397605e-79  1.000000e+00  1.000000e+00  5.397605e-79
#
# ...

# %%
mental_health_df['labels_raw'] = mental_health_df.apply(add, axis=1)
mental_health_df['labels'] = mental_health_df['labels_raw'].apply(lambda x: categ(x))
mental_health_df[['DPQ010', 'DPQ020', 'DPQ030', 'DPQ040', 'DPQ050', 'DPQ060', 'DPQ070',
       'DPQ080', 'DPQ090', 'DPQ100', 'labels_raw', 'labels']]
# Out:
#              DPQ010        DPQ020        DPQ030        DPQ040        DPQ050  \
# 0      5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 1      1.000000e+00  5.397605e-79  1.000000e+00  1.000000e+00  1.000000e+00
# 2      1.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 3      5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 4      5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# ...             ...           ...           ...           ...           ...
# 15508  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 15509  5.397605e-79  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79
# 15510  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 15511  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 15512  5.397605e-79  5.397605e-79  1.000000e+00  1.000000e+00  5.397605e-79
#
# ...

# %% [markdown]
# ## Save the file

# %%
mental_health_df.to_csv('mental_health_df.csv', index=False)

# %% [markdown]
# ## Reference Links

# %% [markdown]
# (asked Albert for help) \
# replace NaN with 0 - https://www.geeksforgeeks.org/replace-nan-values-with-zeros-in-pandas-dataframe/
#
# **Didn't use this, but should be helpful if needed**: https://www.med.umich.edu/1info/FHP/practiceguides/depress/score.pdf
