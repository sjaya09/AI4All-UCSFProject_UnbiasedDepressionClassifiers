# %% [markdown]
# # MERGE Example

# %%
import pandas as pd

# %%
demographic_2011_df = pd.read_csv('../../data/raw/2011-2012_demographic.csv')
mental_health_2011_df = pd.read_csv('../../data/raw/2011-2012_mental_health.csv')
diabetes_2011_df = pd.read_csv('../../data/raw/2011-2012_diabetes.csv')

# %%
all_data_df = demographic_2011_df.merge(mental_health_2011_df, how='outer')
all_data_df = all_data_df.merge(diabetes_2011_df, how='outer')

# %%
all_data_df.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  62161.0       7.0       2.0       1.0      22.0       NaN       3.0
# 1  62162.0       7.0       2.0       2.0       3.0       NaN       1.0
# 2  62163.0       7.0       2.0       1.0      14.0       NaN       5.0
# 3  62164.0       7.0       2.0       2.0      44.0       NaN       3.0
# 4  62165.0       7.0       2.0       2.0      14.0       NaN       4.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DIQ300D  DID310S  DID310D  DID320  \
# 0       3.0       2.0       NaN  ...      NaN      NaN      NaN     NaN
# 1       1.0       1.0      41.0  ...      NaN      NaN      NaN     NaN
# 2       6.0       2.0     177.0  ...      NaN      NaN      NaN     NaN
# 3       3.0       1.0       NaN  ...      NaN      NaN      NaN     NaN
# 4       4.0       2.0     179.0  ...      NaN      NaN      NaN     NaN
#
#    DID330  DID341  DID350  DIQ350U  DIQ360  DIQ080
# 0     NaN     NaN     NaN      NaN     NaN     NaN
# 1     NaN     NaN     NaN      NaN     NaN     NaN
# 2     NaN     NaN     NaN      NaN     NaN     NaN
# 3     NaN     NaN     NaN      NaN     NaN     NaN
# 4     NaN     NaN     NaN      NaN     NaN     NaN
#
# [5 rows x 109 columns]
